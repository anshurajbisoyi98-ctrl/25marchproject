# %% [markdown]
# <a href="https://colab.research.google.com/github/anshurajbisoyi98-ctrl/25marchproject/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
np_arr=np.array([3,3,3,3,3.3,'hello',False])
print(bool(np_arr[-1]))
a=False
print(bool(a))
# Out:
# True
# False

# %% [markdown]
# FUNCTIONS

# %%
a=np.zeros((2,3,4),dtype=int)#3d array
print(type(a[0][0][0]))
# Out:
# <class 'numpy.int64'>

# %%
#. array creation
#array()

#zeros()
#ones()
#empty()
#full()
#arange()
#linespace()

# %%
a=np_arr
ok=np.arange(1,6)
print(ok)
# Out:
# [1 2 3 4 5]

# %%
#full
a=np.linspace(3,12,4,dtype=int)
print(a)
# Out:
# [ 3  6  9 12]

# %%
np.size
# Out:
# <function size at 0x7afb3fbbd5b0>

# %%
print(np.shape)
# Out:
# <function shape at 0x7afb3fb8b9c0>

# %%
np.dtype
# Out:
# numpy.dtype

# %%
a=np.array([2,3,4,4,5,5])
li1=[22345,4,4,4,4,4]
print(2*li1)




b=np.random.randint(12)
print(b)
c=b=np.random.choice(a)
# Out:
# [22345, 4, 4, 4, 4, 4, 22345, 4, 4, 4, 4, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_415/1620901122.py in <cell line: 0>()
#       2 li1=[22345,4,4,4,4,4]
#       3 print(2*li1)
# ----> 4 print(2+li1)
#       5
#       6
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
b=np.array([2,3,4,5,5,4,32,3,4])
c=b.reshape(9,1)

print(c)
# Out:
# [[ 2]
#  [ 3]
#  [ 4]
#  [ 5]
#  [ 5]
#  [ 4]
#  [32]
#  [ 3]
#  [ 4]]

# %%
b=np.array([2,3,4,5,5,4,32,3,4])
c=np.array([4,6,9,4,2,9,5,90,1])
print(b*2)
print(b+c)
print(b-c)
print(b/c)
print(b%c)
# Out:
# [ 4  6  8 10 10  8 64  6  8]
# [ 6  9 13  9  7 13 37 93  5]
# [ -2  -3  -5   1   3  -5  27 -87   3]
# [0.5        0.5        0.44444444 1.25       2.5        0.44444444
#  6.4        0.03333333 4.        ]
# [2 3 4 1 1 4 2 3 0]

# %%
b=np.array([2,3,4,5,5,4,32,3,4])
c=np.array([4,6,9,4,2,9,5,90,1])
print(np.concatenate((b,c)))

b.sort()
print(b)
# Out:
# [ 2  3  4  5  5  4 32  3  4  4  6  9  4  2  9  5 90  1]
# [ 2  3  3  4  4  4  5  5 32]

# %%
#reshape()
#transpose()
#concatenate()
#where()
#sort()
#sum()
#mean()
#std()
#min()
#max()

# %%
b=np.array([2,3,4,5,5,4,32,3,4])
c=np.array([4,6,9,4,2,9,5,90,1])
a=np.where(b>2,b,c)
print(a)
# Out:
# [ 4  3  4  5  5  4 32  3  4]

# %%
# where()
#sort()
#sum()
#mean()
#std()
#min()
#max()
#unique()
#matmul()
#random.randint()
#random.choice()
#random.shuffle()

# %%
b=np.array([2,3,4,5,5,4,32,3,4])
c=np.array([4,6,9,4,2,9,5,90,1])
print(np.sum(b))
print(np.mean(b))
print(np.std(b))
print(np.min(b))
print(np.max(b))
print(np.unique(b))
# Out:
# 62
# 6.888888888888889
# 8.92492694578809
# 2
# 32
# [ 2  3  4  5 32]

# %%
runs=(input("enter the score").split())
runs=np.array(runs,dtype=int)
print(np.sum(runs))
print(np.mean(runs))
print(np.std(runs))
print(np.min(runs))
print(np.max(runs))
# Out:
# enter the score1 2 3 4 5
# 15
# 3.0
# 1.4142135623730951
# 1
# 5
